# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from utils import *

# %%
api_key = "AIzaSyCvUu6zmp6TEGhwKBJmyv2Yh4xcyBv3bfY"
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# run this one per day to get more data
trending_videos = get_trending_videos(youtube)
# trending_videos.to_csv('data/trending_videos.csv', sep='|', index=False)
# Read the existing DSV file (e.g., CSV) containing data from the previous day
existing_data = pd.read_csv('trending_videos.csv', sep='|')

# Merge the new data with the existing data based on the 'Video ID' column
merged_data = pd.concat([existing_data, trending_videos], ignore_index=True)

# Save the merged data back to the DSV file
merged_data.to_csv('trending_videos.csv', sep='|', index=False)
# Out:
# Could not get comments for video ctkW3V0Mh-k

# %%
trending_df = pd.read_csv("data/trending_videos.csv", delimiter='|')
trending_df.head()
# Out:
#       video_id    channelTitle  \
# 0  jlzuDOAUId4   Sam and Colby
# 1  RgWwglvgEX8           TODAY
# 2  7csEy0k0pDc  Safiya Nygaard
# 3  nxc-Acg3vLw            ESPN
# 4  INQw5iRweUI     Ryan Trahan
#
#                                                title  \
# 0  Surviving A Week at The Conjuring House PT 3: ...
# 1  New details emerge on death of ‘Friends’ star ...
# 2            I Melted Every Halloween Candy Together
# 3  Tyson Fury vs. Francis Ngannou HIGHLIGHTS 🎥 | ...
# 4                      I Stayed in Luxury Tiny Homes
#
#                                          description  \
# 0  UNCUT KNOCKING FOOTAGE: https://www.youtube.co...
# 1  As the investigation unfolds into how “Friends...
# 2  HELLO FRIENDS!! Yes, we did something bad. Now...
# 3  Watch highlights of the heavyweight from betwe...
# 4  i love tiny homes!!!!!! --- huge thanks to air...
#
#                                                 tags           publishedAt  \
# 0  ['sam and colby', 'exploring', 'abandoned', 'o...  2023-10-29T18:11:02Z
# 1  ['Al Roker', 'Entertainment', 'Food', 'Health'...  2023-10-30T12:15:03Z
# 2  ['safiya nygaard', 'safiya and tyler', 'tyler ...  2023-10-30T01:51:34Z
# 3  ['tyson fury vs francis ngannou highlights', '...  2023-10-28T23:37:37Z
# 4  ['Ryan', 'Trahan', 'I stayed in luxury tiny ho...  2023-10-29T14:00:15Z
#
#    viewCount  likeCount  favouriteCount  commentCount    duration definition  \
# 0    5727833     298185             NaN       51354.0  PT1H31M13S         hd
# 1    2081612      20983             NaN        1692.0     PT5M55S         hd
# 2    1149514      85568             NaN        4448.0    PT29M57S         hd
# 3    1743539      14998             NaN        7663.0     PT2M17S         hd
# 4    3802116     162377             NaN        7821.0    PT19M20S         hd
#
#    caption
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
