# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from utils import *
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
api_key = "AIzaSyCvUu6zmp6TEGhwKBJmyv2Yh4xcyBv3bfY"
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# run this one per day to get more data
trending_videos, comments = get_trending_videos(youtube)
# trending_videos.to_csv('../data/trending_videos.csv', sep='|', index=False)
# comments.to_csv('../data/trending_video_comments.csv', sep='|', index=False)

# Read the existing DSV file (e.g., CSV) containing data from the previous day
existing_data = pd.read_csv('../data/trending_videos.csv', sep='|')
existing_comments = pd.read_csv('../data/trending_video_comments.csv', sep='|')

# Merge the new data with the existing data based on the 'Video ID' column
merged_data = pd.concat([existing_data, trending_videos], ignore_index=True)
merged_comments = pd.concat([existing_comments, comments], ignore_index=True)

# Save the merged data back to the DSV file
merged_data.to_csv('../data/trending_videos.csv', sep='|', index=False)
merged_comments.to_csv('../data/trending_video_comments.csv', sep='|', index=False)
# Out:
# Could not get comments for video nEj00Gy0SFI
# Could not get comments for video 7-X_7Tk0wXI

# %%
trending_df = pd.read_csv("../data/trending_videos.csv", delimiter='|')
print(trending_df.shape)
trending_df.head()
# Out:
# (200, 15)
#       video_id    channelTitle  \
# 0  nRYpj14DEvk    Dude Perfect
# 1  rg-2DSAL-Yw      Nick Eh 30
# 2  Opxhh9Oh3rg  TheBeatlesVEVO
# 3  VodC8p8RYO4         E! News
# 4  6EiV6oIKPEA      LazarLazar
#
#                                                title  \
# 0                              Zombie Airsoft Battle
# 1                    NickEh30 reacts to OG Fortnite!
# 2  The Beatles - Now And Then (Official Music Video)
# 3  Matthew Perry Laid to Rest: 'Friends' Cast in ...
# 4                                OG Fortnite Is Back
#
#                                          description  \
# 0  5 DUDES vs 1000 ZOMBIES! Our biggest Airsoft B...
# 1  Fortnite Chapter 4 Season 5 time travels us ba...
# 2  Now and Then's eventful journey to fruition to...
# 3  The 'Friends' actor is laid to rest. Perry's c...
# 4  📷MAIN CHANNEL - https://www.youtube.com/lazarb...
#
#                                                 tags           publishedAt  \
# ...
