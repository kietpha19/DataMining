# %%
import pandas as pd
import numpy as np
from dateutil import parser
import isodate
import time

# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# Google API
from googleapiclient.discovery import build

# %%
# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/daniel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/daniel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
api_key = 'AIzaSyAhAjl9v2pxr5M6i-HIIgXhM-sQmtj93E8' 

channel_ids = ['UC295-Dw_tDNtZXFeAPAW6Aw',]
#MR_BEAST=UCX6OQ3DkcsbYNE6H8uQQuVA
#PEWDIEPIE=UC-lHJZR3Gqxm24_Vd_AJ5Yw
#C0C0MELON=UCbCmjCuTUZos6Inko4u57UQ
# DaFuq!?Boom! = UCsSsgPaZ2GSmO6il8Cb5iGA
# mrbeast2 = UC4-79UOlP48-QNGgCko5p2g
# 5 minute crafts = UC295-Dw_tDNtZXFeAPAW6Aw

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    """
    Get channel statistics: title, subscriber count, view count, video count, upload playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    channels_ids: list of channel IDs
    
    Returns:
    Dataframe containing the channel statistics for all channels in the provided list: title, subscriber count, view count, video count, upload playlist
    
    """
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    """
    Get list of video IDs of all videos in the given playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    playlist_id: playlist ID of the channel
    
    Returns:
    List of video IDs of all videos in the playlist
    
    """
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

def get_video_details(youtube, video_ids):
    """
    Get video statistics of all videos with given IDs
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with statistics of videos, i.e.:
        'channelTitle', 'title', 'description', 'tags', 'publishedAt'
        'viewCount', 'likeCount', 'favoriteCount', 'commentCount'
        'duration', 'definition', 'caption'
    """
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

def get_comments_in_videos(youtube, video_ids):
    """
    Get top level comments as text from all videos with given IDs (only the first 10 comments due to quote limit of Youtube API)
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with video IDs and associated top level comment in text.
    
    """
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %% [markdown]
# ### Get channel statistics

# %% [markdown]
# Using the `get_channel_stats` function defined below, now we are going to obtain the channel statistics for the 9 channels in scope.

# %%
channel_data = get_channel_stats(youtube, channel_ids)

# %% [markdown]
# Now I can print out the data and take a look at the channel statistics overview.

# %%
channel_data
# Out:
#        channelName subscribers        views totalVideos  \
# 0  5-Minute Crafts    80400000  26724491109        6688
#
#                  playlistId
# 0  UU295-Dw_tDNtZXFeAPAW6Aw

# %% [markdown]
# I noticed the count columns in `channel_data` is currently in string format, so I will convert them into numeric so that we can visualize and do numeric operations on them.

# %%
# Convert count columns to numeric columns
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Let's take a look at the number of subscribers per channel to have a view of how popular the channels are when compared with one another.

# %% [markdown]
# ### Get video statistics for all the channels

# %% [markdown]
# In the next step, we will obtain the video statistics for all the channels.

# %%
# Create a dataframe with video statistics and comments from all channels
Total = channel_data['totalVideos'].sum()

video_df = pd.DataFrame()
comments_df = pd.DataFrame()
tic = time.perf_counter()
for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)
    # get comment data
    comments_data = get_comments_in_videos(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = video_df._append(video_data, ignore_index=True)
    comments_df = comments_df._append(comments_data, ignore_index=True)
toc = time.perf_counter()
print(f"Obtained statistics in {toc - tic:0.4f} seconds for {Total} videos")
# Out:
# Getting video information from channel: 5-Minute Crafts
# Could not get comments for video y838QNcu7EI
# Could not get comments for video lIdBkW_Aoc8
# Could not get comments for video l-E4vVnST2E
# Could not get comments for video Nf_XgSMTzxk
# Could not get comments for video wpNGbGVxaNQ
# Could not get comments for video q1CVwHFYXPY
# Could not get comments for video KFrKFwOlU24
# Could not get comments for video HyZew0syq-4
# Could not get comments for video A0kea4RT6AY
# Could not get comments for video S9sV83Yr3N4
# Could not get comments for video -DpqX0it7Vc
# Could not get comments for video QTlcC3kJjLA
# Could not get comments for video IzW0B6qQKWI
# Could not get comments for video SAT0_6hF0E8
# Could not get comments for video RaRoELK_yX8
# Could not get comments for video hZSH3cGFSgM
# Could not get comments for video -ykQjuwofUU
# Could not get comments for video xzygCwBPrUM
# Could not get comments for video 8EBfCXCzaog
# Could not get comments for video ORFFrm4ifLY
# Could not get comments for video YzcpGFhR_4U
# Could not get comments for video kxdAY7V_zSw
# Could not get comments for video TkSsRxlaWnQ
# Could not get comments for video MH2xVNCed20
# Could not get comments for video LLIAgyD4yko
# Could not get comments for video c8OaJBTLf3A
# Could not get comments for video 4s1XmaBmgds
# Could not get comments for video 8_okblVXMCg
# Could not get comments for video fu9oFLDVDbo
# Could not get comments for video lDJuiVLNY6s
# Could not get comments for video _7Tl61PViTE
# Could not get comments for video 3-jBGB3ENxQ
# Could not get comments for video D9aa4w1CbCw
# Could not get comments for video f95bJYP3Qew
# Could not get comments for video EWvEPyHyfvQ
# Could not get comments for video JtKXUfmrrTI
# Could not get comments for video Ml1Rf2itXi8
# Could not get comments for video bA4EOOxWnIc
# Could not get comments for video kQcPkYSVxI4
# Could not get comments for video bvUfuTJubPk
# Could not get comments for video 7JlvDl3MOIU
# Could not get comments for video AqCN5JPWBdU
# Could not get comments for video DPyPs_sb5xo
# Could not get comments for video Hj35Tu0tP-o
# Could not get comments for video jBouHL-EaUQ
# Could not get comments for video DUCzRzoSUMk
# Could not get comments for video Ja4TblFapuM
# Could not get comments for video aUj-bqZ90VI
# Could not get comments for video DygGJ2wcydg
# Could not get comments for video FW8hojEUKWQ
# Could not get comments for video vAalvqyPjfs
# Could not get comments for video BS7m0ei0yOs
# Could not get comments for video HSVWIHcg5_A
# Could not get comments for video KvLFEJGwyfw
# Could not get comments for video a3TdgjSi9Do
# Could not get comments for video VefAN20WKxo
# Could not get comments for video tJyXy7qQvGw
# Could not get comments for video MpkqDKAOj60
# Could not get comments for video ezKw4bEhK4c
# Could not get comments for video 5J_ZAK188es
# Could not get comments for video Ugk1g2N0ZcA
# Could not get comments for video R8FPBtc12nI
# Could not get comments for video wjsXEaGhba0
# Could not get comments for video h2_xRJA5nyg
# Could not get comments for video MtSEUtGpSEo
# Could not get comments for video XIy1ObhhGdQ
# Could not get comments for video gmCa9GT5LhA
# Could not get comments for video FudaCKFl_dc
# Could not get comments for video _T9kC21Lmu8
# Could not get comments for video SJ3k52DMk0o
# Could not get comments for video wrS64foQQsc
# Could not get comments for video dADKV6gqUJc
# Could not get comments for video LxGF350o8hE
# Could not get comments for video hkLjkLuj94A
# Could not get comments for video 9Kgt20YO54E
# Could not get comments for video XY0SgHwHlmg
# Could not get comments for video fvvegDwzDNY
# Could not get comments for video 0ECAqLYFcXE
# Could not get comments for video -vAK6UDkwhQ
# Could not get comments for video ppb-DJ2E68U
# Could not get comments for video 3i8IsetgQ8M
# Could not get comments for video aDXuYuUyCYI
# Could not get comments for video rsdMstRte50
# Could not get comments for video zYQ8eOFAS1E
# Could not get comments for video 499QX3lk2Ec
# Could not get comments for video lXr5U0hDW5I
# Could not get comments for video uRGRcTcr_pg
# Could not get comments for video sUnVGJEuwAU
# Could not get comments for video _VupE8FQOuU
# Could not get comments for video hQoOueQHx60
# Could not get comments for video RJMVayit7NM
# Could not get comments for video h3dmQ_d0HQ4
# Could not get comments for video PqkuyUDHYy0
# Could not get comments for video OvN3MSzozZs
# Could not get comments for video TvDQ5imXAp0
# Could not get comments for video BS9o3VQMpwI
# Could not get comments for video kAj7NwcnM7Y
# Could not get comments for video fte85pzb68s
# Could not get comments for video JrpXosnVMNE
# Could not get comments for video 75xsNC04ots
# Could not get comments for video jm1Ua3uYrpE
# Could not get comments for video tRRRXpeSZyM
# Could not get comments for video CkIQJWQgP2Q
# Could not get comments for video DHRzbCl1W_E
# Could not get comments for video amuaPE_xzDQ
# Could not get comments for video n2eQUPM8K78
# Could not get comments for video P9FyzMIV01M
# Could not get comments for video FrCXQM_2Sbg
# Could not get comments for video SJEWX3ZaR9s
# Could not get comments for video r7666koyg1Q
# Could not get comments for video QSUoMyUCR8E
# Could not get comments for video 2s5VQccnvS0
# Could not get comments for video QXTXDC8vGOg
# Could not get comments for video T2kfQY3IHxs
# Could not get comments for video QCayMgHJdRk
# Could not get comments for video dQLnqGq2w1U
# Could not get comments for video 1GaVimPGQS0
# Could not get comments for video g7gSm5CspV4
# Could not get comments for video VrEZJndb-54
# Could not get comments for video vOZXHkLFAJ4
# Could not get comments for video KOwfUi-1cQo
# Could not get comments for video f0n2dv6pQK4
# Could not get comments for video 35hZJaUtONQ
# Could not get comments for video VvNbvMp3lP0
# Could not get comments for video rfSYbmWr3ZE
# Could not get comments for video xQ859w5fI10
# Could not get comments for video 9M2jdOZA3zY
# Could not get comments for video lWE0fXAVFXM
# Could not get comments for video ACpsPRPzM4E
# Could not get comments for video paz8jKGYgyw
# Could not get comments for video IHb9IlqVQyg
# Could not get comments for video StRDX8U5Njs
# Could not get comments for video AutCG8n8HpU
# Could not get comments for video Qu36o2K_MWY
# Could not get comments for video KlX9W7BECNI
# Could not get comments for video -FM3mOfJU0Q
# Could not get comments for video 46eT6j0os5k
# Could not get comments for video OZIuMXgLmLA
# Could not get comments for video cVZOH8meOpA
# Could not get comments for video JEwj7YNAb8w
# Could not get comments for video sShfjFc2DPM
# Could not get comments for video LKMXmuPFigs
# Could not get comments for video tBvSHzTZiwo
# Could not get comments for video nvwYgaytaMM
# Could not get comments for video NTss-oTiOtI
# Could not get comments for video KwAGmyVaaes
# Could not get comments for video RjJho8NyhfA
# Could not get comments for video QVxT3AmV5gQ
# Could not get comments for video wvCjc7Goz9k
# Could not get comments for video GAZvmIqIaZM
# Could not get comments for video x_sR5cl1_6k
# Could not get comments for video IZwRImgtB2Y
# Could not get comments for video rFuGGLO6WDo
# Could not get comments for video wRukHeaREL4
# Could not get comments for video YF6jPVgQfhE
# Could not get comments for video Dws2Ope7jI4
# Could not get comments for video b3TpsF6Kszg
# Could not get comments for video -5gefXJpqU4
# Could not get comments for video Ms6q6LmIugw
# Could not get comments for video UBq_ziB48OU
# Could not get comments for video 9TpyStP2-Sw
# Could not get comments for video hc0b38sapcA
# Could not get comments for video PAWjAv1Z8jk
# Could not get comments for video 7OzSMTjJqSY
# Could not get comments for video tWrqG6M8W7I
# Could not get comments for video H7TLFUanEz0
# Could not get comments for video RSCqIM_3Py4
# Could not get comments for video DisePVJ27XQ
# Could not get comments for video ZhiN1ciGFG0
# Could not get comments for video JDjVQQ0ze34
# Could not get comments for video v9-5Z0wMUXQ
# Could not get comments for video xA7z-5GJhmU
# Could not get comments for video qj7Pxcyt19Q
# Could not get comments for video atYGwgqRFVU
# Could not get comments for video aq-vtbFPqAc
# Could not get comments for video R5EsHIS5P_g
# Could not get comments for video kErBliBZ9vc
# Could not get comments for video 926CUToHoT8
# Could not get comments for video 668eR82sY60
# Could not get comments for video QXUFfWtyUWI
# Could not get comments for video 4W5o6xXMgCc
# Could not get comments for video LdNYUN8ErU4
# Could not get comments for video 2unXc2i_m6g
# Could not get comments for video IHf438Zsiyo
# Could not get comments for video niJMY28BHNw
# Could not get comments for video UBSWRZhkqYw
# Could not get comments for video cVCcS1qL_7U
# Could not get comments for video 9Z8K5G-ugIw
# Could not get comments for video c4Wpo-DJ52M
# Could not get comments for video Dd2V9mfvJ38
# Could not get comments for video qxpZew_i9UM
# Could not get comments for video Rumaxw23G2I
# Could not get comments for video gy0WM6T5rgc
# Could not get comments for video dTgLkl2asZQ
# Could not get comments for video PnYTzjejhhs
# Could not get comments for video nd11xjWon5Y
# Could not get comments for video buxZquyWizw
# Could not get comments for video N8d_CTR-t50
# Could not get comments for video hC4zjHrW8gk
# Could not get comments for video HgGwcheB1kw
# Could not get comments for video ZenlQ_B7uOQ
# Could not get comments for video Od99jv-evGQ
# Could not get comments for video -gPWT3AAaxc
# Could not get comments for video -newcfQNZdw
# Could not get comments for video Ad4bFPl5s00
# Could not get comments for video OnF7yR0IC7M
# Could not get comments for video nMCEB8GF1XE
# Could not get comments for video rhhHxlZvDCw
# Could not get comments for video mXNd8UpOMVo
# Could not get comments for video 83s-JZZsc-E
# Could not get comments for video GA0xbcoHof4
# Could not get comments for video _Em8RJWFa2g
# Could not get comments for video mwvuhiboYYY
# Could not get comments for video qaWx0Htzx8k
# Could not get comments for video qrabKawvaDU
# Could not get comments for video dooyljC0nqw
# Could not get comments for video fk0RbRV7QcY
# Could not get comments for video 49c1TvCNXGE
# Could not get comments for video _wokBaOPJj0
# Could not get comments for video YrHg43sA2ZI
# Could not get comments for video iJ7Imko_Ggw
# Could not get comments for video 2l8Me2wGybs
# Could not get comments for video t0-kBAWtn1E
# Could not get comments for video mORJbuJbALM
# Could not get comments for video b9mCUgZNXxQ
# Could not get comments for video j_pAcBI7ofo
# Could not get comments for video oTVHg0vX1Fg
# Could not get comments for video MtMGm-cjwo4
# Could not get comments for video Fo9EbhLWW1s
# Could not get comments for video 0T8K5iJ6mz0
# Could not get comments for video wnxfWhspiYI
# Could not get comments for video c29BcdPs9PQ
# Could not get comments for video pv_UAkf7mAI
# Could not get comments for video xUsmbuhhq6Y
# Could not get comments for video LzdYaHBFv-s
# Could not get comments for video hkgV_8n-iI0
# Could not get comments for video 77XSqhWT66A
# Could not get comments for video 21CRZthRAMc
# Could not get comments for video FrPZ28_437E
# Could not get comments for video zvPhPaqhlQw
# Could not get comments for video wGHw6JBv3s4
# Could not get comments for video SgSRd7zhcnY
# Could not get comments for video _halJ4yrmGQ
# Could not get comments for video w_3K1sPX7mg
# Could not get comments for video _4bVfUp_5N4
# Could not get comments for video G_fV8zzaSHc
# Could not get comments for video yuEZaXeXoog
# Could not get comments for video r2VZ-qNp7Ys
# Could not get comments for video fa2g4igpn20
# Could not get comments for video lWSXHFPqBfo
# Could not get comments for video zuFMA6hi_ZM
# Could not get comments for video wWZsTEzYCDw
# Could not get comments for video lRHfuH2tD5Q
# Could not get comments for video Vq_WrH4mmGY
# Could not get comments for video foMm6pE0L7o
# Could not get comments for video bMHGju6H4uo
# Could not get comments for video NQYtgTKFB3M
# Could not get comments for video E_U-T65hBjQ
# Could not get comments for video 10lqF2HUlw8
# Could not get comments for video yiHpQ7nwvaw
# Could not get comments for video 00mJdVLN1tE
# Could not get comments for video _Rte0iSQEC4
# Could not get comments for video wfU11xoRGhE
# Could not get comments for video H6GMBNuCmZw
# Could not get comments for video D9N4xXGZREg
# Could not get comments for video 2HTNvQXuFhM
# Could not get comments for video Nd4bRu-YtCU
# Could not get comments for video Hcuqsc3Cw_s
# Could not get comments for video P7zHdNgdGuI
# Could not get comments for video Ov9qD06t5gI
# Could not get comments for video FoUAqwnuyKE
# Could not get comments for video kqgmnTWwfFQ
# Could not get comments for video 18hKzLrFxVk
# Could not get comments for video ZzIWPTUDat0
# Could not get comments for video zTgeMCgJmQU
# Could not get comments for video v9y3M5X2ua4
# Could not get comments for video ZZRortQ7tRo
# Could not get comments for video cMeKz8Aulog
# Could not get comments for video vBDGyVgRf_g
# Could not get comments for video xrkvgsfDAX0
# Could not get comments for video nDtqGRYGeHI
# Could not get comments for video EeW66DL3bmU
# Could not get comments for video JRb0xDXwAj8
# Could not get comments for video L3O5ECQYP_s
# Could not get comments for video -QbVyLL2IIg
# Could not get comments for video _kcDsexQgUA
# Could not get comments for video _RwkOEAML0w
# Could not get comments for video AYgmOnd5zJc
# Could not get comments for video rmKmjYnNQdc
# Could not get comments for video FKsket2OIcM
# Could not get comments for video odrL3cdRuAQ
# Could not get comments for video d4TPTfrmiW0
# Could not get comments for video ULo4wE1UdzU
# Could not get comments for video bNqIyuni1ZY
# Could not get comments for video OQuDzNdD6zk
# Could not get comments for video 2L8QXYO0Dik
# Could not get comments for video jbZLyqTywzI
# Could not get comments for video P1GT2N1OZnI
# Could not get comments for video v2RSjkpMp0o
# Could not get comments for video CvANP3DOcBo
# Could not get comments for video Kd3fBrj2cRA
# Could not get comments for video 11cNVEBucA4
# Could not get comments for video iyZBlAWQ9nE
# Could not get comments for video lqhmqMrSt0Q
# Could not get comments for video 7wkMI-xqay0
# Could not get comments for video FwdmGwyvpRA
# Could not get comments for video V2FKD3xYLUg
# Could not get comments for video 2j69K3ozCjA
# Could not get comments for video NPzlzkqomvo
# Could not get comments for video ynXJQYVQGxU
# Could not get comments for video LjQY8ZaKKrg
# Could not get comments for video wvURFgWR1YI
# Could not get comments for video Z1-Yu1AJFYs
# Could not get comments for video bfLd-QJdp1s
# Could not get comments for video u8MTuCVJ0AE
# Could not get comments for video G7AKhOWS4Wo
# Could not get comments for video z-gMhLsaNCE
# Could not get comments for video jfFnZVOVUBQ
# Could not get comments for video ixMoP72nlw4
# Could not get comments for video jHbd7GMZ8uo
# Could not get comments for video kx7o38YOuWo
# Could not get comments for video PBa_ZFXkGdI
# Could not get comments for video s7FXy0vF-Jk
# Could not get comments for video 2y0UGkOgAQY
# Could not get comments for video MS2MbaivFc4
# Could not get comments for video -A1ePjpVPPw
# Could not get comments for video sVkWdZYLOzw
# Could not get comments for video 33lcomWXiJQ
# Could not get comments for video aHRtn7g-QPw
# Could not get comments for video MdTS-LgP4Kw
# Could not get comments for video c56ZqXmR2uM
# Could not get comments for video R79rk64KwiM
# Could not get comments for video 6Ikl3XFrjOc
# Could not get comments for video Jt8w2x7cjeY
# Could not get comments for video 9s6932ZHHH0
# Could not get comments for video jEUdz2sn5No
# Could not get comments for video DHhOxQpJ9h4
# Could not get comments for video mtTQAizKNWE
# Could not get comments for video XwFFjO_6YKc
# Could not get comments for video b6aLP_vba0g
# Could not get comments for video BoGfJsS2gEg
# Could not get comments for video EvyCgQkorQs
# Could not get comments for video ufvagIrvgaA
# Could not get comments for video G9x5lkAyju4
# Could not get comments for video ON_eOGYlrY0
# Could not get comments for video xZyyXgKiPHo
# Could not get comments for video kPf9DLxTv6M
# Could not get comments for video M0NhDD4iqiE
# Could not get comments for video Uq6z0Bg9dX8
# Could not get comments for video fcPqtuTCciQ
# Could not get comments for video J2frL5kQURk
# Could not get comments for video wnK_kBF140o
# Could not get comments for video fbGyC5_XwcU
# Could not get comments for video eAZrzB7v8IY
# Could not get comments for video 4g1QmHt_Bko
# Could not get comments for video bV_nCfuxaMI
# Could not get comments for video STv0MSpiJGc
# Could not get comments for video n7ooSuojb9I
# Could not get comments for video 0pdp-3lZodk
# Could not get comments for video tmEngC7M6B0
# Could not get comments for video VwhNUcFEJSA
# Could not get comments for video vEyn5JeBnro
# Could not get comments for video leKn0MdlnX0
# Could not get comments for video ykaRnsCVA24
# Could not get comments for video Ohd7jGr26xk
# Could not get comments for video KobgZiEQScw
# Could not get comments for video 3nf1qBln2gk
# Could not get comments for video D_IUYLh4viY
# Could not get comments for video Z0WyI2obU9Y
# Could not get comments for video znManE9_Xk4
# Could not get comments for video x_wi_XTdmcE
# Obtained statistics in 1757.9248 seconds for 6688 videos

# %%
video_df
# Out:
#          video_id     channelTitle  \
# 0     _lpfFbYnbOM  5-Minute Crafts
# 1     NAW3bdt3xh8  5-Minute Crafts
# 2     fgUr6kfnv9c  5-Minute Crafts
# 3     B_x5rqgxqmc  5-Minute Crafts
# 4     tyLhe5QnebM  5-Minute Crafts
# ...           ...              ...
# 6683  RA9GjoRhcSE  5-Minute Crafts
# 6684  KtetRv4kfog  5-Minute Crafts
# 6685  AEp338eSyDM  5-Minute Crafts
# 6686  JmFQavE0sPM  5-Minute Crafts
# 6687  s_99ugf_diM  5-Minute Crafts
#
#                                                   title  \
# 0       Illuminate Your World with Rock Art! 🌟✨ #shorts
# 1          Easy School Crafts for Creative Students 📚✂️
# 2     DIY Jewelry Ideas ✨💍Unique Accessories You Can...
# 3     🌟✂️ 5-Minute Crafts Historic Event! ✂️🌟 #short...
# 4     Delicious Snack and Treat Ideas That Are Quick...
# ...                                                 ...
# 6683  Amazing life hack; how to recycle old crayons ...
# 6684  How to DIY a magnetic memo holder l 5-MINUTE C...
# 6685  How to turn your old T-shirt into a pillowcase...
# 6686  3 tricks to clean without harsh chemicals l 5-...
# 6687  5 essential DIY hacks that you need to know  l...
#
#                                             description  \
# 0     Get Your Rock Painting Kit Now at Walmart! ➡️ ...
# 1     Hi friends! 🧩🍭 Welcome to our creative corner!...
# 2     Hi everyone! 🤩🤗 Welcome to a world of creativi...
# 3     🌟✂️ 5-Minute Crafts Historic Event! ✂️🌟\r\n🛒 N...
# 4     Hi everyone! 💗🍭 Join us in this mouthwatering ...
# ...                                                 ...
# 6683  Amazing life hack; how to recycle old crayons ...
# 6684  How to DIY a magnetic memo holder l 5-MINUTE C...
# 6685  How to turn a T-shirt into a pillowcase (NO SE...
# 6686  3 tricks to clean without harsh chemicals l 5-...
# 6687  5 essential DIY hacks that you need to know  l...
#
#                                                    tags           publishedAt  \
# 0     [5 minute craft, 5 minutes craft, 5-minute cra...  2023-11-17T17:00:35Z
# 1     [5 minute craft, 5 minutes craft, 5-minute cra...  2023-11-17T13:00:19Z
# 2     [5 minute craft, 5 minutes craft, 5-minute cra...  2023-11-17T11:00:40Z
# 3     [5 minute craft, 5 minutes craft, 5-minute cra...  2023-11-16T15:00:09Z
# 4     [5 minute craft, 5 minutes craft, 5-minute cra...  2023-11-16T13:00:48Z
# ...                                                 ...                   ...
# 6683  [how to, cryons, crayons, short video, turoria...  2016-11-17T14:52:05Z
# 6684  [fridge, home decor, how to, tutorial, homedec...  2016-11-17T11:39:53Z
# 6685  [tshirt, lifehack, life hack, DIY, home decor,...  2016-11-17T11:05:23Z
# 6686  inutecrafts, crafts, chemicals, lifehack, l...  2016-11-16T21:20:07Z
# 6687  inutecrafts, 5 minute craft, 5 minute craft...  2016-11-16T20:31:25Z
#
#      viewCount likeCount favouriteCount commentCount duration definition  \
# 0        11513       638           None            4    PT31S         hd
# 1        25981       309           None           25  PT1H49S         hd
# 2        15873       212           None           13  PT8M59S         hd
# 3        70549      1511           None            7    PT15S         hd
# 4        48395       437           None           30   PT1H2S         hd
# ...        ...       ...            ...          ...      ...        ...
# 6683     89421      1078           None           57    PT55S         hd
# 6684     75419      1535           None           94    PT52S         hd
# 6685    157822      2549           None          167   PT1M2S         hd
# 6686    105074      2113           None          216  PT1M21S         hd
# 6687    509311     13266           None         3984  PT1M13S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 6683   false
# 6684   false
# 6685   false
# 6686   false
# 6687   false
#
# [6688 rows x 13 columns]

# %%
comments_df
# Out:
#          video_id                                           comments
# 0     _lpfFbYnbOM  [Finally saying something, I dont know, Nice, ...
# 1     NAW3bdt3xh8  [You could easily make all of these crafts fro...
# 2     fgUr6kfnv9c  [Hello friends, I’m gaymer, but I don’t suppor...
# 3     B_x5rqgxqmc  [🌟✂️ 5-Minute Crafts Historic Event! ✂️🌟\r\n🛒 ...
# 4     tyLhe5QnebM  [i love this video so much ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤...
# ...           ...                                                ...
# 6312  RA9GjoRhcSE  [Back When They Were Good. 😔😔😔, you can make a...
# 6313  KtetRv4kfog  [Marathon Watching 7/18/22 Cool Craft!, Nice.,...
# 6314  AEp338eSyDM  [Back when 5 min crafts were useful :'D, This ...
# 6315  JmFQavE0sPM  [Who's watching this video in 2023, When 5 min...
# 6316  s_99ugf_diM  [Good times, The good ol’ days, when people we...
#
# [6317 rows x 2 columns]

# %%
# Write video data to CSV file for future references
video_df.to_csv('video_data.csv')
comments_df.to_csv('comments_data.csv')

# %% [markdown]
# ## Preprocessing & Feature engineering
#
# To be able to make use of the data for analysis, we need to perform a few pre-processing steps. Firstly, I would like reformat some columns, especially the date and time columns such as "pushlishedAt" and "duration". In addition, I also think it is necessary to enrich the data with some new features that might be useful for understanding the videos' characteristics.

# %% [markdown]
# ### Check for empty values

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# 2017-11-24T08:30:00Z    2
# 2019-08-17T12:30:00Z    2
# 2016-11-16T20:31:25Z    1
# 2020-08-01T00:30:03Z    1
# 2020-08-03T12:30:00Z    1
#                        ..
# 2018-10-21T12:30:00Z    1
# 2018-10-21T07:30:00Z    1
# 2018-10-20T23:30:01Z    1
# 2018-10-20T18:30:01Z    1
# 2023-11-17T17:00:35Z    1
# Name: publishedAt, Length: 6686, dtype: int64

# %% [markdown]
# Next, we need to check if the data type of the columns are correct. I have checked the data types and indeed some count columns such as view count and comment count are currently not in correct data type. In this step, we convert these count columns into integer.

# %%
cols = ['viewCount', 'likeCount', 'commentCount']
video_df[cols] = video_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %% [markdown]
# ### Enriching data

# %% [markdown]
# I want to enrich the data for further analyses, for example:
#
# - create published date column with another column showing the day in the week the video was published, which will be useful for later analysis.
#
# - convert video duration to seconds instead of the current default string format
#
# - calculate number of tags for each video
#
# - calculate comments and likes per 1000 view ratio
#
# - calculate title character length

# %%
# Create publish day (in the week) column
video_df['publishedAt'] =  video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
# Add number of tags
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
# Title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

# %% [markdown]
# Let's look at the video dataset at this point to see if everything went well. It looks good - now we will proceed to exploratory analysis part.

# %%
df = video_df.drop('favouriteCount', axis=1)
df.head()
# Out:
#       video_id     channelTitle  \
# 0  _lpfFbYnbOM  5-Minute Crafts
# 1  NAW3bdt3xh8  5-Minute Crafts
# 2  fgUr6kfnv9c  5-Minute Crafts
# 3  B_x5rqgxqmc  5-Minute Crafts
# 4  tyLhe5QnebM  5-Minute Crafts
#
#                                                title  \
# 0    Illuminate Your World with Rock Art! 🌟✨ #shorts
# 1       Easy School Crafts for Creative Students 📚✂️
# 2  DIY Jewelry Ideas ✨💍Unique Accessories You Can...
# 3  🌟✂️ 5-Minute Crafts Historic Event! ✂️🌟 #short...
# 4  Delicious Snack and Treat Ideas That Are Quick...
#
#                                          description  \
# 0  Get Your Rock Painting Kit Now at Walmart! ➡️ ...
# 1  Hi friends! 🧩🍭 Welcome to our creative corner!...
# 2  Hi everyone! 🤩🤗 Welcome to a world of creativi...
# 3  🌟✂️ 5-Minute Crafts Historic Event! ✂️🌟\r\n🛒 N...
# 4  Hi everyone! 💗🍭 Join us in this mouthwatering ...
#
#                                                 tags  \
# 0  [5 minute craft, 5 minutes craft, 5-minute cra...
# 1  [5 minute craft, 5 minutes craft, 5-minute cra...
# 2  [5 minute craft, 5 minutes craft, 5-minute cra...
# 3  [5 minute craft, 5 minutes craft, 5-minute cra...
# 4  [5 minute craft, 5 minutes craft, 5-minute cra...
#
#                 publishedAt  viewCount  likeCount  commentCount duration  \
# 0 2023-11-17 17:00:35+00:00    11513.0      638.0           4.0    PT31S
# 1 2023-11-17 13:00:19+00:00    25981.0      309.0          25.0  PT1H49S
# 2 2023-11-17 11:00:40+00:00    15873.0      212.0          13.0  PT8M59S
# 3 2023-11-16 15:00:09+00:00    70549.0     1511.0           7.0    PT15S
# 4 2023-11-16 13:00:48+00:00    48395.0      437.0          30.0   PT1H2S
#
#   definition caption pushblishDayName  durationSecs  tagsCount  likeRatio  \
# 0         hd   false           Friday          31.0         20  55.415617
# 1         hd   false           Friday        3649.0         32  11.893307
# 2         hd   false           Friday         539.0         32  13.356013
# 3         hd   false         Thursday          15.0         20  21.417738
# 4         hd   false         Thursday        3602.0         35   9.029858
#
#    commentRatio  titleLength
# 0      0.347433           47
# 1      0.962242           44
# 2      0.819001           59
# 3      0.099222           80
# 4      0.619899           66

# %%
#updated csv
# Write video data to CSV file for future references
video_df.to_csv('video_data_UP.csv')
